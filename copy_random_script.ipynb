# %%
import os, random, shutil

# %%
#Prompting user to enter number of files to select randomly along with directory
source='Trials_With_Tables'
dest='sample_set'
no_of_files=100
print("%"*25+"{ Details Of Transfer }"+"%"*25)
print("\n\nList of Files Moved to %s :-"%(dest))

#Using for loop to randomly choose multiple files
for i in range(no_of_files):
    #Variable random_file stores the name of the random file chosen
    random_file=random.choice(os.listdir(source))
    print("%d} %s"%(i+1,random_file))
    source_file="%s\%s"%(source,random_file)
    dest_file=dest
    #"shutil.move" function moves file from one directory to another
    shutil.copy2(source_file,dest_file)

print("\n\n"+"$"*33+"[ Files Moved Successfully ]"+"$"*33)
# Out:
# %%%%%%%%%%%%%%%%%%%%%%%%%{ Details Of Transfer }%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
# List of Files Moved to sample_set :-
# 1} clinical_trial_rank_0069.pdf
# 2} clinical_trial_rank_0620.pdf
# 3} clinical_trial_rank_0311.pdf
# 4} clinical_trial_rank_0772.pdf
# 5} clinical_trial_rank_0552.pdf
# 6} clinical_trial_rank_0188.pdf
# 7} clinical_trial_rank_0783.pdf
# 8} clinical_trial_rank_0726.pdf
# 9} clinical_trial_rank_0148.pdf
# 10} clinical_trial_rank_0361.pdf
# 11} clinical_trial_rank_0619.pdf
# 12} clinical_trial_rank_0350.pdf
# 13} clinical_trial_rank_0428.pdf
# 14} clinical_trial_rank_0725.pdf
# 15} clinical_trial_rank_0213.pdf
# 16} clinical_trial_rank_0412.pdf
# 17} clinical_trial_rank_0565.pdf
# 18} clinical_trial_rank_0452.pdf
# 19} clinical_trial_rank_0449.pdf
# 20} clinical_trial_rank_0406.pdf
# 21} clinical_trial_rank_0575.pdf
# 22} clinical_trial_rank_0317.pdf
# 23} clinical_trial_rank_0407.pdf
# 24} clinical_trial_rank_0542.pdf
# 25} clinical_trial_rank_0756.pdf
# 26} clinical_trial_rank_0589.pdf
# 27} clinical_trial_rank_0211.pdf
# 28} clinical_trial_rank_0073.pdf
# 29} clinical_trial_rank_0401.pdf
# 30} clinical_trial_rank_0380.pdf
# 31} clinical_trial_rank_0614.pdf
# 32} clinical_trial_rank_0447.pdf
# 33} clinical_trial_rank_0606.pdf
# 34} clinical_trial_rank_0182.pdf
# 35} clinical_trial_rank_0122.pdf
# 36} clinical_trial_rank_0453.pdf
# 37} clinical_trial_rank_0610.pdf
# 38} clinical_trial_rank_0621.pdf
# 39} clinical_trial_rank_0674.pdf
# 40} clinical_trial_rank_0496.pdf
# 41} clinical_trial_rank_0522.pdf
# 42} clinical_trial_rank_0377.pdf
# 43} clinical_trial_rank_0451.pdf
# 44} clinical_trial_rank_0708.pdf
# 45} clinical_trial_rank_0797.pdf
# 46} clinical_trial_rank_0265.pdf
# 47} clinical_trial_rank_0355.pdf
# 48} clinical_trial_rank_0027.pdf
# 49} clinical_trial_rank_0468.pdf
# 50} clinical_trial_rank_0544.pdf
# 51} clinical_trial_rank_0054.pdf
# 52} clinical_trial_rank_0351.pdf
# 53} clinical_trial_rank_0336.pdf
# 54} clinical_trial_rank_0605.pdf
# 55} clinical_trial_rank_0404.pdf
# 56} clinical_trial_rank_0592.pdf
# 57} clinical_trial_rank_0002.pdf
# 58} clinical_trial_rank_0551.pdf
# 59} clinical_trial_rank_0175.pdf
# 60} clinical_trial_rank_0779.pdf
# 61} clinical_trial_rank_0298.pdf
# 62} clinical_trial_rank_0623.pdf
# 63} clinical_trial_rank_0082.pdf
# 64} clinical_trial_rank_0579.pdf
# 65} clinical_trial_rank_0727.pdf
# 66} clinical_trial_rank_0137.pdf
# 67} clinical_trial_rank_0591.pdf
# 68} clinical_trial_rank_0731.pdf
# 69} clinical_trial_rank_0061.pdf
# 70} clinical_trial_rank_0684.pdf
# 71} clinical_trial_rank_0420.pdf
# 72} clinical_trial_rank_0342.pdf
# 73} clinical_trial_rank_0346.pdf
# 74} clinical_trial_rank_0329.pdf
# 75} clinical_trial_rank_0742.pdf
# 76} clinical_trial_rank_0687.pdf
# 77} clinical_trial_rank_0005.pdf
# 78} clinical_trial_rank_0596.pdf
# 79} clinical_trial_rank_0775.pdf
# 80} clinical_trial_rank_0181.pdf
# 81} clinical_trial_rank_0753.pdf
# 82} clinical_trial_rank_0032.pdf
# 83} clinical_trial_rank_0141.pdf
# 84} clinical_trial_rank_0485.pdf
# 85} clinical_trial_rank_0053.pdf
# 86} clinical_trial_rank_0001.pdf
# 87} clinical_trial_rank_0529.pdf
# 88} clinical_trial_rank_0528.pdf
# 89} clinical_trial_rank_0140.pdf
# 90} clinical_trial_rank_0193.pdf
# 91} clinical_trial_rank_0131.pdf
# 92} clinical_trial_rank_0566.pdf
# 93} clinical_trial_rank_0628.pdf
# 94} clinical_trial_rank_0197.pdf
# 95} clinical_trial_rank_0367.pdf
# 96} clinical_trial_rank_0118.pdf
# 97} clinical_trial_rank_0639.pdf
# 98} clinical_trial_rank_0771.pdf
# 99} clinical_trial_rank_0501.pdf
# 100} clinical_trial_rank_0093.pdf
#
#
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$[ Files Moved Successfully ]$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
